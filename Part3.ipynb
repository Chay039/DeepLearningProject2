# %%
import matplotlib.pyplot as plt

# Extract configurations and accuracies for FC models
FC_results = [['Configuration-1', 3, [32, 64, 128], 64, 0.001, 0.8569], ['Configuration-2', 3, [64, 128, 256], 512, 0.001, 0.856], ['Configuration-3', 3, [128, 256, 512], 64, 0.001, 0.8609], ['Configuration-4', 2, [64, 128], 64, 0.001, 0.8687], ['Configuration-5', 2, [32, 64], 64, 0.001, 0.8589], ['Configuration-6', 2, [128, 256], 64, 0.001, 0.8704], ['Configuration-7', 2, [256, 512], 64, 0.001, 0.8633], ['Configuration-8', 1, [64], 64, 0.001, 0.8625], ['Configuration-9', 1, [128], 64, 0.001, 0.873], ['Configuration-10', 1, [256], 64, 0.001, 0.8736], ['Configuration-11', 3, [32, 64, 128], 128, 0.001, 0.8408], ['Configuration-12', 4, [64, 128, 256, 512], 128, 0.001, 0.8429], ['Configuration-13', 2, [128, 256], 256, 0.001, 0.8584], ['Configuration-14', 1, [512], 256, 0.001, 0.8771], ['Configuration-15', 4, [64, 128, 256, 512], 32, 0.001, 0.8222]]

fc_configs = [result[0] for result in FC_results]
fc_accuracies = [result[5] * 100 for result in FC_results]

# Extract configurations and accuracies for CNN models
# Corrected CNN results
CNN_results = [
    ({'num_layers': 2, 'filters': 32, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 64, 'optimizer': 'adam', 'learning_rate': 0.001, 'dropout': False}, 0.9053999781608582),
    ({'num_layers': 2, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 64, 'optimizer': 'sgd', 'learning_rate': 0.01, 'dropout': False}, 0.8416000008583069),
    ({'num_layers': 2, 'filters': 32, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 64, 'optimizer': 'rmsprop', 'learning_rate': 0.001, 'dropout': True, 'dropout_rate': 0.2}, 0.8998000025749207),
    ({'num_layers': 2, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'learning_rate': 0.001, 'dropout': True, 'dropout_rate': 0.2}, 0.9125000238418579),
    ({'num_layers': 3, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'optimizer': 'sgd', 'learning_rate': 0.01, 'dropout': True, 'dropout_rate': 0.3}, 0.8295999765396118),
    ({'num_layers': 3, 'filters': 32, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'optimizer': 'adam', 'learning_rate': 0.001, 'dropout': False}, 0.8978999853134155),
    ({'num_layers': 3, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 64, 'optimizer': 'rmsprop', 'learning_rate': 0.001, 'dropout': True, 'dropout_rate': 0.3}, 0.9031999707221985),
    ({'num_layers': 2, 'filters': 32, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 64, 'optimizer': 'sgd', 'learning_rate': 0.001, 'dropout': True, 'dropout_rate': 0.2}, 0.7458999752998352),
    ({'num_layers': 2, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 64, 'optimizer': 'adam', 'learning_rate': 0.001, 'dropout': False}, 0.9093999862670898),
    ({'num_layers': 2, 'filters': 32, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'optimizer': 'rmsprop', 'learning_rate': 0.001, 'dropout': True, 'dropout_rate': 0.2}, 0.9010000228881836),
    ({'num_layers': 2, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'optimizer': 'sgd', 'learning_rate': 0.01, 'dropout': True, 'dropout_rate': 0.2}, 0.8521000146865845),
    ({'num_layers': 3, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'optimizer': 'adam', 'learning_rate': 0.001, 'dropout': False}, 0.9089000225067139),
    ({'num_layers': 3, 'filters': 32, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'optimizer': 'rmsprop', 'learning_rate': 0.001, 'dropout': True, 'dropout_rate': 0.2}, 0.8978000283241272),
    ({'num_layers': 3, 'filters': 64, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 64, 'optimizer': 'sgd', 'learning_rate': 0.001, 'dropout': True, 'dropout_rate': 0.3}, 0.7037000060081482),
    ({'num_layers': 2, 'filters': 32, 'kernel_size': (3, 3), 'pool_size': (2, 2), 'batch_size': 32, 'optimizer': 'adam', 'learning_rate': 0.001, 'dropout': False}, 0.911899983882904)]

cnn_configs = [idx + 1 for idx, _ in enumerate(CNN_results)]
cnn_accuracies = [acc * 100 for _, acc in CNN_results]

# Plot accuracies for FC and CNN models
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(fc_configs, fc_accuracies, marker='o', color='green', label='Fully Connected Models')
ax.plot(cnn_configs, cnn_accuracies, marker='s', color='blue', label='CNN Models')
ax.set_xlabel('Configuration')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Test Performance : FC vs CNN Models')
ax.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define model configurations
fc_configs = [
    {"hidden_sizes": [32, 16], "num_layers": 2},
    {"hidden_sizes": [64, 32, 16], "num_layers": 3},
    {"hidden_sizes": [128, 64, 32, 16], "num_layers": 4},
    {"hidden_sizes": [256, 128, 64, 32, 16], "num_layers": 5},
]

cnn_configs = [
    {"kernel_size": (3, 3), "pool_size": (2, 2)},
    {"kernel_size": (5, 5), "pool_size": (2, 2)},
    {"kernel_size": (3, 3), "pool_size": (3, 3)},
    {"kernel_size": (5, 5), "pool_size": (3, 3)},
]

# Simulate training results (replace with your actual results)
fc_train_accuracies = [0.85, 0.88, 0.92, 0.91]
fc_test_accuracies = [0.82, 0.86, 0.89, 0.87]

cnn_train_accuracies = [0.92, 0.89, 0.94, 0.91]
cnn_test_accuracies = [0.90, 0.86, 0.92, 0.88]

# Plot for Fully Connected Networks
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.plot(range(len(fc_configs)), fc_train_accuracies, label='Train Accuracy')
plt.plot(range(len(fc_configs)), fc_test_accuracies, label='Test Accuracy')
plt.xticks(range(len(fc_configs)), [str(config["num_layers"]) for config in fc_configs], rotation=45)
plt.xlabel('Number of Hidden Layers')
plt.ylabel('Accuracy')
plt.title('Fully Connected Networks')
plt.legend()

# Plot for Convolutional Neural Networks
plt.subplot(1, 2, 2)
plt.plot(range(len(cnn_configs)), cnn_train_accuracies, label='Train Accuracy')
plt.plot(range(len(cnn_configs)), cnn_test_accuracies, label='Test Accuracy')
plt.xticks(range(len(cnn_configs)), [str(config["kernel_size"]) + ", " + str(config["pool_size"]) for config in cnn_configs], rotation=45)
plt.xlabel('Kernel Size, Pooling Size')
plt.ylabel('Accuracy')
plt.title('Convolutional Neural Networks')
plt.legend()

plt.tight_layout()
plt.show()
